# %%
import pandas as pd
pd.options.display.max_columns = None
df = pd.read_csv("yearly_full_release_long_format.csv")
df.head()
# Out:
#           Area Country code  Year Area type Continent Ember region   EU  OECD  \
# 0  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
# 1  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
# 2  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
# 3  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
# 4  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
#
#    G20   G7  Category     Subcategory                               Variable  \
# 0  0.0  0.0  Capacity  Aggregate fuel                                  Clean
# 1  0.0  0.0  Capacity  Aggregate fuel                                 Fossil
# 2  0.0  0.0  Capacity  Aggregate fuel                   Gas and Other Fossil
# 3  0.0  0.0  Capacity  Aggregate fuel  Hydro, Bioenergy and Other Renewables
# 4  0.0  0.0  Capacity  Aggregate fuel                             Renewables
#
# ...

# %%
Europa = df[df['Ember region'] == 'Europe']
Europa
# Out:
#                   Area Country code  Year Area type Continent Ember region  \
# 2904           Albania          ALB  2000   Country    Europe       Europe
# 2905           Albania          ALB  2000   Country    Europe       Europe
# 2906           Albania          ALB  2000   Country    Europe       Europe
# 2907           Albania          ALB  2000   Country    Europe       Europe
# 2908           Albania          ALB  2000   Country    Europe       Europe
# ...                ...          ...   ...       ...       ...          ...
# 304649  United Kingdom          GBR  2021   Country    Europe       Europe
# 304650  United Kingdom          GBR  2021   Country    Europe       Europe
# 304651  United Kingdom          GBR  2021   Country    Europe       Europe
# 304652  United Kingdom          GBR  2021   Country    Europe       Europe
# 304653  United Kingdom          GBR  2021   Country    Europe       Europe
#
# ...

# %%
#Selected Region Europe
Europa.to_json("Europe.json", orient = 'table')

# %%
Europa.head()
# Out:
#          Area Country code  Year Area type Continent Ember region   EU  OECD  \
# 2904  Albania          ALB  2000   Country    Europe       Europe  0.0   0.0
# 2905  Albania          ALB  2000   Country    Europe       Europe  0.0   0.0
# 2906  Albania          ALB  2000   Country    Europe       Europe  0.0   0.0
# 2907  Albania          ALB  2000   Country    Europe       Europe  0.0   0.0
# 2908  Albania          ALB  2000   Country    Europe       Europe  0.0   0.0
#
#       G20   G7  Category     Subcategory  \
# 2904  0.0  0.0  Capacity  Aggregate fuel
# 2905  0.0  0.0  Capacity  Aggregate fuel
# 2906  0.0  0.0  Capacity  Aggregate fuel
# 2907  0.0  0.0  Capacity  Aggregate fuel
# 2908  0.0  0.0  Capacity  Aggregate fuel
#
#                                    Variable Unit  Value  YoY absolute change  \
# 2904                                  Clean   GW   1.45                  NaN
# 2905                                 Fossil   GW   0.19                  NaN
# ...

# %%
set(Europa['Area'])
# Out:
# {'Albania',
#  'Austria',
#  'Belarus',
#  'Belgium',
#  'Bosnia Herzegovina',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Estonia',
#  'Faroe Islands (the)',
#  'Finland',
#  'France',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Kosovo',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Moldova',
#  'Montenegro',
#  'Netherlands',
#  'North Macedonia',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russian Federation (the)',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'Ukraine',
#  'United Kingdom'}

# %%
paises = ['Austria','Belgium','Bulgaria','Croatia','Cyprus','Czechia','Denmark','Estonia','Finland','France','Germany','Greece','Hungary',
 'Ireland',
 'Italy','Latvia',
 'Lithuania',
 'Luxembourg',
 'Malta','Netherlands',
 'Poland',
 'Portugal',
 'Romania','Slovakia',
 'Slovenia',
 'Spain',
 'Sweden']
for k in paises: 
    Europa27 = Europa.loc[Europa.Area.isin(paises)]

# %%
set(Europa27['Area'])
# Out:
# {'Austria',
#  'Belgium',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Netherlands',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden'}

# %%
Europa27
# Out:
#            Area Country code  Year Area type Continent Ember region   EU  \
# 17358   Austria          AUT  2000   Country    Europe       Europe  1.0
# 17359   Austria          AUT  2000   Country    Europe       Europe  1.0
# 17360   Austria          AUT  2000   Country    Europe       Europe  1.0
# 17361   Austria          AUT  2000   Country    Europe       Europe  1.0
# 17362   Austria          AUT  2000   Country    Europe       Europe  1.0
# ...         ...          ...   ...       ...       ...          ...  ...
# 278711   Sweden          SWE  2021   Country    Europe       Europe  1.0
# 278712   Sweden          SWE  2021   Country    Europe       Europe  1.0
# 278713   Sweden          SWE  2021   Country    Europe       Europe  1.0
# 278714   Sweden          SWE  2021   Country    Europe       Europe  1.0
# 278715   Sweden          SWE  2021   Country    Europe       Europe  1.0
#
#         OECD  G20   G7                Category     Subcategory  \
# ...

# %%
Europa27.to_json("Europe27.json", orient = 'table')

# %%
df_2021 = df_EU[(df_EU['Category']=='Electricity generation') & (df_EU['Year']== 2021) & (df_EU['Subcategory'] == 'Fuel') & (df_EU['Unit'] == '%')][['Area','Variable','Value']]
df_2021 = df_2021.pivot_table('Value', ['Area'], 'Variable')
df_2021 = df_2021[['Hydro', 'Coal','Nuclear','Wind','Bioenergy','Solar','Other Fossil','Other Renewables','Gas' ]]
df_2021.sort_values(by='Hydro',  axis = 0, ascending = True, inplace = True,)

# %%
df_2021
# Out:
# Variable     Hydro      Coal   Nuclear      Wind  Bioenergy    Solar  \
# Area
# Albania   19.42575  15.87425  14.49925  10.90275    5.97175  3.86325
#
# Variable  Other Fossil  Other Renewables       Gas
# Area
# Albania        7.52075             0.171  21.77175

# %%
df_2000 = df_EU[(df_EU['Category']=='Electricity generation') & (df_EU['Year']== 2000) & (df_EU['Subcategory'] == 'Fuel') & (df_EU['Unit'] == '%')][['Area','Variable','Value']]
df_2000 = df_2000.pivot_table('Value', ['Area'], 'Variable')
df_2000
# Out:
# Variable  Bioenergy   Coal       Gas      Hydro    Nuclear  Other Fossil  \
# Area
# Albania    0.913095  27.05  16.73619  23.810238  16.002143     14.437143
#
# Variable  Other Renewables    Solar      Wind
# Area
# Albania           0.459286  0.00119  0.590714

# %%
df_nuc_yeu = df_EU[df_EU['Variable'] == 'CO2 intensity']
df_nuc_yeu
# Out:
#            Area Country code  Year Area type Continent Ember region   EU  \
# 2959    Albania          ALB  2000   Country    Europe       Europe  0.0
# 3025    Albania          ALB  2001   Country    Europe       Europe  0.0
# 3091    Albania          ALB  2002   Country    Europe       Europe  0.0
# 3157    Albania          ALB  2003   Country    Europe       Europe  0.0
# 3223    Albania          ALB  2004   Country    Europe       Europe  0.0
# ...         ...          ...   ...       ...       ...          ...  ...
# 304379  Albania          GBR  2017   Country    Europe       Europe  0.0
# 304445  Albania          GBR  2018   Country    Europe       Europe  0.0
# 304511  Albania          GBR  2019   Country    Europe       Europe  0.0
# 304577  Albania          GBR  2020   Country    Europe       Europe  0.0
# 304643  Albania          GBR  2021   Country    Europe       Europe  0.0
#
#         OECD  G20   G7                Category    Subcategory       Variable  \
# ...

# %%
df_c_f = df_EU[(df_EU['Category']=='Electricity generation') & (df_EU['Year']== 2021) & ((df_EU['Variable'] == 'Clean')|(df_EU['Variable'] == 'Fossil')) & (df_EU['Unit'] == '%')][['Area','Variable','Value']]
df_c_f = df_c_f.pivot_table('Value', ['Area'], 'Variable').sort_values(by='Clean', ascending = True)
df_c_f
# Out:
# Variable     Clean     Fossil
# Area
# Albania   54.83375  44.065122
